# %%
#!pip install catboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import time
from catboost import Pool
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
test = pd.read_csv('./data/test.csv')

# %%
# 환불/환불한 구매내역 삭제한 데이터
df = pd.read_pickle('./data/data_2.pkl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8025045 entries, 826307 to 8851351
# Data columns (total 29 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   month_id                    int8
#  1   shop_id                     int8
#  2   item_id                     int16
#  3   cnt_month                   float32
#  4   city_id                     int8
#  5   cat_id                      int8
#  6   main_cat                    int8
#  7   sub_cat                     int8
#  8   year                        int16
#  9   month                       int8
#  10  sales_month                 int8
#  11  cnt_month_1                 float32
#  12  cnt_month_2                 float32
#  13  cnt_month_3                 float32
#  14  item_id_mean_cnt_1          float32
#  15  item_id_mean_cnt_2          float32
#  16  item_id_mean_cnt_3          float32
#  17  sub_cat_mean_cnt_1          float32
#  18  sub_cat_mean_cnt_2          float32
#  19  sub_cat_mean_cnt_3          float32
#  20  price_mean_mean_cnt_1       float32
#  21  price_mean_mean_cnt_2       float32
#  22  price_mean_mean_cnt_3       float32
#  23  item_id/city_id_mean_cnt_1  float32
#  24  item_id/city_id_mean_cnt_2  float32
#  25  item_id/city_id_mean_cnt_3  float32
#  26  shop_id/cat_id_mean_cnt_1   float32
#  27  shop_id/cat_id_mean_cnt_2   float32
#  28  shop_id/cat_id_mean_cnt_3   float32
# dtypes: float32(19), int16(2), int8(8)
# memory usage: 734.7 MB

# %%
df.head()
# Out:
#         month_id  shop_id  item_id  cnt_month  city_id  cat_id  main_cat  \
# 826307         3       25     8092        3.0       13      40        11
# 826308         3       25     7850        3.0       13      30         8
# 826309         3       25     8051        3.0       13      66        14
# 826310         3       25     8088        1.0       13      55        13
# 826311         3       25     8089        1.0       13      55        13
#
#         sub_cat  year  month  ...  sub_cat_mean_cnt_3  price_mean_mean_cnt_1  \
# 826307        6  2013      4  ...                 0.0               1.401494
# 826308       54  2013      4  ...                 0.0               1.482536
# 826309       47  2013      4  ...                 0.0               0.000000
# 826310        4  2013      4  ...                 0.0               1.482536
# 826311        4  2013      4  ...                 0.0               0.000000
#
#         price_mean_mean_cnt_2  price_mean_mean_cnt_3  \
# 826307               1.369542                    0.0
# 826308               1.464628                    0.0
# 826309               0.000000                    0.0
# 826310               0.000000                    0.0
# 826311               0.000000                    0.0
#
#         item_id/city_id_mean_cnt_1  item_id/city_id_mean_cnt_2  \
# 826307                    1.000000                    2.142857
# 826308                    3.714286                    2.285714
# 826309                    0.000000                    0.428571
# 826310                    0.285714                    0.000000
# 826311                    0.571429                    0.000000
#
#         item_id/city_id_mean_cnt_3  shop_id/cat_id_mean_cnt_1  \
# 826307                         0.0                   1.088162
# 826308                         0.0                   3.675141
# 826309                         0.0                   1.827586
# 826310                         0.0                   0.599068
# 826311                         0.0                   0.599068
#
#         shop_id/cat_id_mean_cnt_2  shop_id/cat_id_mean_cnt_3
# 826307                   1.048877                        0.0
# 826308                   2.277354                        0.0
# 826309                   1.389474                        0.0
# 826310                   0.559843                        0.0
# 826311                   0.559843                        0.0
#
# [5 rows x 29 columns]

# %%
s = ['cnt_month', 'cnt_month_1','cnt_month_2', 'cnt_month_3', 'item_id_mean_cnt_1','item_id_mean_cnt_2', 'item_id_mean_cnt_3', 
        'sub_cat_mean_cnt_1','sub_cat_mean_cnt_2', 'sub_cat_mean_cnt_3', 'price_mean_mean_cnt_1',
       'price_mean_mean_cnt_2', 'price_mean_mean_cnt_3','item_id/city_id_mean_cnt_1', 'item_id/city_id_mean_cnt_2',
       'item_id/city_id_mean_cnt_3', 'shop_id/cat_id_mean_cnt_1','shop_id/cat_id_mean_cnt_2', 'shop_id/cat_id_mean_cnt_3']

# %%
# value clip(0~20)
df[s] = df[s].clip(0, 20)

# %%
# train/validation/test data split
X_train = df[df['month_id'] < 33].drop(['cnt_month'], axis=1)
Y_train = df[df['month_id'] < 33]['cnt_month']

X_valid = df[df['month_id'] == 33].drop(['cnt_month'], axis=1)
Y_valid = df[df['month_id'] == 33]['cnt_month']

X_test = df[df['month_id'] == 34].drop(['cnt_month'], axis=1)

# %%
cat = [1,2,4,5,6,7] # 범주형 데이터 설정

# %%
model = CatBoostRegressor(
    max_depth=10,              # 트리의 최대 깊이
    n_estimators = 1000,       # 최대 트리 수
    eta = 0.3,                 # 학습률 : 증감률을 줄이는데 사용
    random_seed=123           # 훈련에 사용되는 랜덤 시드
    )

# %%
ts = time.time()
model.fit(
    X_train, Y_train, 
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)],  # 유효성 검사 데이터 세트
    cat_features=cat,                                    # 범주형 데이터 설정     
    verbose=True,                                      # True : 상세로그수준 / False : 자동로그수준 / int : 상세로그수준을 사용, 매개변수로 로깅기간 사용 
    early_stopping_rounds = 20                         # 검증횟수 설정
    )

print('소요시간: ',time.time()-ts)
# Out:
# 0:	learn: 1.0719474	test: 1.0686737	test1: 0.9782826	best: 0.9782826 (0)	total: 22.1s	remaining: 6h 7m 46s
# 1:	learn: 0.9659265	test: 0.9566407	test1: 0.9288570	best: 0.9288570 (1)	total: 43.2s	remaining: 5h 59m 13s
# 2:	learn: 0.9065411	test: 0.8954993	test1: 0.9069445	best: 0.9069445 (2)	total: 1m 3s	remaining: 5h 49m 16s
# 3:	learn: 0.8653298	test: 0.8522670	test1: 0.8955618	best: 0.8955618 (3)	total: 1m 20s	remaining: 5h 36m 5s
# 4:	learn: 0.8450442	test: 0.8325750	test1: 0.8931040	best: 0.8931040 (4)	total: 1m 41s	remaining: 5h 37m 41s
# 5:	learn: 0.8253447	test: 0.8130685	test1: 0.8897974	best: 0.8897974 (5)	total: 2m 3s	remaining: 5h 41m 53s
# 6:	learn: 0.8126189	test: 0.7997656	test1: 0.8778340	best: 0.8778340 (6)	total: 2m 31s	remaining: 5h 57m 12s
# 7:	learn: 0.8013852	test: 0.7868031	test1: 0.8700943	best: 0.8700943 (7)	total: 3m	remaining: 6h 12m 20s
# 8:	learn: 0.7951303	test: 0.7795210	test1: 0.8679960	best: 0.8679960 (8)	total: 3m 23s	remaining: 6h 13m 19s
# 9:	learn: 0.7898997	test: 0.7732726	test1: 0.8657031	best: 0.8657031 (9)	total: 3m 44s	remaining: 6h 10m 42s
# 10:	learn: 0.7835817	test: 0.7660081	test1: 0.8641056	best: 0.8641056 (10)	total: 4m 7s	remaining: 6h 10m 15s
# 11:	learn: 0.7810608	test: 0.7634369	test1: 0.8612713	best: 0.8612713 (11)	total: 4m 30s	remaining: 6h 11m 14s
# 12:	learn: 0.7769444	test: 0.7585569	test1: 0.8610050	best: 0.8610050 (12)	total: 4m 57s	remaining: 6h 17m 2s
# 13:	learn: 0.7716260	test: 0.7525946	test1: 0.8597276	best: 0.8597276 (13)	total: 5m 27s	remaining: 6h 24m 53s
# 14:	learn: 0.7687993	test: 0.7488056	test1: 0.8584272	best: 0.8584272 (14)	total: 6m 4s	remaining: 6h 39m 8s
# 15:	learn: 0.7658734	test: 0.7455689	test1: 0.8580180	best: 0.8580180 (15)	total: 6m 35s	remaining: 6h 45m 5s
# 16:	learn: 0.7638104	test: 0.7430335	test1: 0.8563358	best: 0.8563358 (16)	total: 7m 1s	remaining: 6h 45m 56s
# 17:	learn: 0.7599847	test: 0.7391453	test1: 0.8521593	best: 0.8521593 (17)	total: 7m 27s	remaining: 6h 46m 44s
# 18:	learn: 0.7572569	test: 0.7363317	test1: 0.8507820	best: 0.8507820 (18)	total: 7m 56s	remaining: 6h 49m 46s
# 19:	learn: 0.7556516	test: 0.7347174	test1: 0.8492988	best: 0.8492988 (19)	total: 8m 18s	remaining: 6h 46m 44s
# 20:	learn: 0.7519340	test: 0.7314875	test1: 0.8481434	best: 0.8481434 (20)	total: 8m 47s	remaining: 6h 50m 4s
# 21:	learn: 0.7481380	test: 0.7297354	test1: 0.8473832	best: 0.8473832 (21)	total: 9m 20s	remaining: 6h 54m 58s
# 22:	learn: 0.7426344	test: 0.7240792	test1: 0.8467752	best: 0.8467752 (22)	total: 9m 57s	remaining: 7h 2m 56s
# 23:	learn: 0.7406241	test: 0.7220361	test1: 0.8469832	best: 0.8467752 (22)	total: 10m 25s	remaining: 7h 3m 54s
# 24:	learn: 0.7389793	test: 0.7203325	test1: 0.8466929	best: 0.8466929 (24)	total: 10m 49s	remaining: 7h 2m 4s
# 25:	learn: 0.7374500	test: 0.7185308	test1: 0.8468662	best: 0.8466929 (24)	total: 11m 16s	remaining: 7h 2m 13s
# 26:	learn: 0.7361526	test: 0.7172459	test1: 0.8461812	best: 0.8461812 (26)	total: 11m 36s	remaining: 6h 58m 5s
# 27:	learn: 0.7341803	test: 0.7151520	test1: 0.8427480	best: 0.8427480 (27)	total: 12m 9s	remaining: 7h 2m 16s
# 28:	learn: 0.7321818	test: 0.7129551	test1: 0.8420349	best: 0.8420349 (28)	total: 12m 31s	remaining: 6h 59m 37s
# 29:	learn: 0.7307880	test: 0.7114757	test1: 0.8419491	best: 0.8419491 (29)	total: 13m 5s	remaining: 7h 3m 8s
# 30:	learn: 0.7297247	test: 0.7103749	test1: 0.8421119	best: 0.8419491 (29)	total: 13m 28s	remaining: 7h 1m 2s
# 31:	learn: 0.7287298	test: 0.7093657	test1: 0.8427421	best: 0.8419491 (29)	total: 13m 56s	remaining: 7h 1m 50s
# 32:	learn: 0.7279160	test: 0.7085597	test1: 0.8425948	best: 0.8419491 (29)	total: 14m 22s	remaining: 7h 1m 9s
# 33:	learn: 0.7269108	test: 0.7074780	test1: 0.8420306	best: 0.8419491 (29)	total: 14m 42s	remaining: 6h 57m 59s
# 34:	learn: 0.7261411	test: 0.7066810	test1: 0.8417318	best: 0.8417318 (34)	total: 15m 3s	remaining: 6h 55m 1s
# 35:	learn: 0.7239598	test: 0.7053139	test1: 0.8422980	best: 0.8417318 (34)	total: 15m 30s	remaining: 6h 55m 3s
# 36:	learn: 0.7230128	test: 0.7042889	test1: 0.8422803	best: 0.8417318 (34)	total: 15m 53s	remaining: 6h 53m 43s
# 37:	learn: 0.7209994	test: 0.7025218	test1: 0.8420956	best: 0.8417318 (34)	total: 16m 37s	remaining: 7h 1m 5s
# 38:	learn: 0.7201826	test: 0.7016374	test1: 0.8441757	best: 0.8417318 (34)	total: 17m 4s	remaining: 7h 49s
# 39:	learn: 0.7188130	test: 0.7000934	test1: 0.8447267	best: 0.8417318 (34)	total: 17m 39s	remaining: 7h 3m 52s
# 40:	learn: 0.7144460	test: 0.6961222	test1: 0.8441711	best: 0.8417318 (34)	total: 18m 13s	remaining: 7h 6m 14s
# 41:	learn: 0.7139624	test: 0.6955456	test1: 0.8437473	best: 0.8417318 (34)	total: 18m 46s	remaining: 7h 8m 14s
# 42:	learn: 0.7115311	test: 0.6931232	test1: 0.8434751	best: 0.8417318 (34)	total: 19m 19s	remaining: 7h 9m 58s
# 43:	learn: 0.7100791	test: 0.6915315	test1: 0.8425340	best: 0.8417318 (34)	total: 19m 56s	remaining: 7h 13m 18s
# 44:	learn: 0.7092896	test: 0.6905009	test1: 0.8424855	best: 0.8417318 (34)	total: 20m 33s	remaining: 7h 16m 14s
# 45:	learn: 0.7083222	test: 0.6895602	test1: 0.8423932	best: 0.8417318 (34)	total: 21m 9s	remaining: 7h 18m 45s
# 46:	learn: 0.7048944	test: 0.6863612	test1: 0.8435651	best: 0.8417318 (34)	total: 21m 48s	remaining: 7h 22m 19s
# 47:	learn: 0.7039045	test: 0.6853755	test1: 0.8440572	best: 0.8417318 (34)	total: 22m 21s	remaining: 7h 23m 26s
# 48:	learn: 0.7013513	test: 0.6833297	test1: 0.8449210	best: 0.8417318 (34)	total: 23m 1s	remaining: 7h 26m 59s
# 49:	learn: 0.7005600	test: 0.6825144	test1: 0.8445604	best: 0.8417318 (34)	total: 23m 27s	remaining: 7h 25m 39s
# 50:	learn: 0.6998156	test: 0.6814961	test1: 0.8446158	best: 0.8417318 (34)	total: 23m 51s	remaining: 7h 23m 48s
# 51:	learn: 0.6991489	test: 0.6808108	test1: 0.8444832	best: 0.8417318 (34)	total: 24m 18s	remaining: 7h 23m 5s
# 52:	learn: 0.6984899	test: 0.6801387	test1: 0.8445585	best: 0.8417318 (34)	total: 24m 37s	remaining: 7h 20m 8s
# 53:	learn: 0.6978690	test: 0.6795674	test1: 0.8443746	best: 0.8417318 (34)	total: 25m 5s	remaining: 7h 19m 38s
# 54:	learn: 0.6973733	test: 0.6791138	test1: 0.8442135	best: 0.8417318 (34)	total: 25m 37s	remaining: 7h 20m 15s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8417317984
# bestIteration = 34
#
# Shrink model to first 35 iterations.
# 소요시간:  1595.169719696045

# %%
Y_pred = model.predict(X_valid)

# %%
submission = pd.DataFrame({
    "ID": X_valid.index, 
    "item_cnt_month": Y_pred
})
x = submission['ID'].head(200)
y_pred = submission['item_cnt_month'].head(200)
y_true = Y_valid.head(200)
fig = plt.figure(figsize=(25, 5))
ax = fig.add_subplot(111)
ax.plot(x, y_pred, label = 'predictive value', color = 'red')
ax.plot(x, y_true, label = 'actual value', color = 'green')

ax.legend()

plt.show()

# %%
Y_test = model.predict(X_test)

# %%
# 제출 파일 생성
submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('./submission/submission_CatBoost_2022022801.csv', index=False)
